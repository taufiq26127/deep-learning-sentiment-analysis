# %%
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, Dense

# %%
vocab_size = 10000
max_len = 200

(X_train, y_train), (X_test, y_test) = imdb.load_data(num_words=vocab_size)

# %%
X_train = pad_sequences(X_train, maxlen=max_len, padding='post')
X_test = pad_sequences(X_test, maxlen=max_len, padding='post')

print(f"Training data shape: {X_train.shape}")
print(f"Testing data shape: {X_test.shape}")
# Out:
# Training data shape: (25000, 200)
# Testing data shape: (25000, 200)

# %%
model = Sequential([
    Embedding(input_dim=vocab_size, output_dim=128),
    SimpleRNN(128, activation='tanh', return_sequences=False),
    Dense(1, activation='sigmoid')
])

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, None, 128)         1280000
#
#  simple_rnn (SimpleRNN)      (None, 128)               32896
#
#  dense (Dense)               (None, 1)                 129
#
# =================================================================
# Total params: 1,313,025
# Trainable params: 1,313,025
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train, 
                    epochs=5, 
                    batch_size=32, 
                    validation_split=0.2)
# Out:
# Epoch 1/5
# 625/625 [==============================] - 104s 163ms/step - loss: 0.6989 - accuracy: 0.5035 - val_loss: 0.6908 - val_accuracy: 0.5290
# Epoch 2/5
# 625/625 [==============================] - 99s 159ms/step - loss: 0.6804 - accuracy: 0.5458 - val_loss: 0.6946 - val_accuracy: 0.5506
# Epoch 3/5
# 625/625 [==============================] - 100s 159ms/step - loss: 0.6270 - accuracy: 0.6113 - val_loss: 0.6525 - val_accuracy: 0.5810
# Epoch 4/5
# 625/625 [==============================] - 101s 162ms/step - loss: 0.5759 - accuracy: 0.6726 - val_loss: 0.6519 - val_accuracy: 0.6018
# Epoch 5/5
# 625/625 [==============================] - 100s 161ms/step - loss: 0.5712 - accuracy: 0.6784 - val_loss: 0.5456 - val_accuracy: 0.7552

# %%
# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss}")
print(f"Test Accuracy: {accuracy}")
# Out:
# 782/782 [==============================] - 21s 27ms/step - loss: 0.5517 - accuracy: 0.7432
# Test Loss: 0.5517348647117615
# Test Accuracy: 0.7432399988174438
