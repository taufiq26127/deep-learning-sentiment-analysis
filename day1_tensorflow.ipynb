# %%
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, Dense

# %%
vocab_size = 10000
max_len = 200

(X_train, y_train), (X_test, y_test) = imdb.load_data(num_words=vocab_size)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 [==============================] - 6s 0us/step
# Training data shape: (25000, 200)

# %%
X_train = pad_sequences(X_train, maxlen=max_len, padding='post')
X_test = pad_sequences(X_test, maxlen=max_len, padding='post')

print(f"Training data shape: {X_train.shape}")
print(f"Testing data shape: {X_test.shape}")
# Out:
# Training data shape: (25000, 200)
# Testing data shape: (25000, 200)

# %%
model = Sequential([
    Embedding(input_dim=vocab_size, output_dim=128),
    SimpleRNN(32, activation='tanh', return_sequences=False),
    Dense(1, activation='sigmoid')
])

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, None, 128)         1280000
#
#  simple_rnn (SimpleRNN)      (None, 32)                5152
#
#  dense (Dense)               (None, 1)                 33
#
# =================================================================
# Total params: 1,285,185
# Trainable params: 1,285,185
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train, 
                    epochs=5, 
                    batch_size=32, 
                    validation_split=0.2)
# Out:
# Epoch 1/5
# 625/625 [==============================] - 121s 185ms/step - loss: 0.6841 - accuracy: 0.5254 - val_loss: 0.6660 - val_accuracy: 0.5634
# Epoch 2/5
# 625/625 [==============================] - 110s 175ms/step - loss: 0.5674 - accuracy: 0.6560 - val_loss: 0.6906 - val_accuracy: 0.5712
# Epoch 3/5
# 625/625 [==============================] - 112s 180ms/step - loss: 0.4258 - accuracy: 0.7278 - val_loss: 0.8274 - val_accuracy: 0.5446
# Epoch 4/5
# 625/625 [==============================] - 111s 177ms/step - loss: 0.3822 - accuracy: 0.7463 - val_loss: 0.8811 - val_accuracy: 0.5578
# Epoch 5/5
# 625/625 [==============================] - 109s 175ms/step - loss: 0.3703 - accuracy: 0.7581 - val_loss: 0.9381 - val_accuracy: 0.5516

# %%
# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss}")
print(f"Test Accuracy: {accuracy}")
# Out:
# 782/782 [==============================] - 23s 29ms/step - loss: 0.9297 - accuracy: 0.5460
# Test Loss: 0.9296901822090149
# Test Accuracy: 0.5460000038146973
