# %%
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, Dense, LSTM

# %%
vocab_size = 10000
max_len = 250

(X_train, y_train), (X_test, y_test) = imdb.load_data(num_words=vocab_size)

# %%
X_train = pad_sequences(X_train, maxlen=max_len, padding='post')
X_test = pad_sequences(X_test, maxlen=max_len, padding='post')

print(f"Training data shape: {X_train.shape}")
print(f"Testing data shape: {X_test.shape}")
# Out:
# Training data shape: (25000, 250)
# Testing data shape: (25000, 250)

# %% [markdown]
# ## Model RNN

# %%
rnn_model = Sequential([
    Embedding(input_dim=vocab_size, output_dim=128),
    SimpleRNN(128, activation='tanh', return_sequences=False),
    Dense(1, activation='sigmoid')
])

# %%
rnn_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

rnn_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, None, 128)         1280000
#
#  simple_rnn_1 (SimpleRNN)    (None, 128)               32896
#
#  dense_2 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 1,313,025
# Trainable params: 1,313,025
# Non-trainable params: 0
# _________________________________________________________________

# %%
rnn_history = rnn_model.fit(X_train, y_train, 
                            epochs=10,
                            batch_size=64,
                            validation_split=0.2)
# Out:
# Epoch 1/10
# 313/313 [==============================] - 89s 282ms/step - loss: 0.6971 - accuracy: 0.5088 - val_loss: 0.6922 - val_accuracy: 0.5142
# Epoch 2/10
# 313/313 [==============================] - 103s 331ms/step - loss: 0.6925 - accuracy: 0.5185 - val_loss: 0.6919 - val_accuracy: 0.5226
# Epoch 3/10
# 313/313 [==============================] - 103s 328ms/step - loss: 0.6882 - accuracy: 0.5318 - val_loss: 0.6944 - val_accuracy: 0.5222
# Epoch 4/10
# 313/313 [==============================] - 102s 325ms/step - loss: 0.6725 - accuracy: 0.5630 - val_loss: 0.7001 - val_accuracy: 0.5228
# Epoch 5/10
# 313/313 [==============================] - 104s 332ms/step - loss: 0.6474 - accuracy: 0.5791 - val_loss: 0.6871 - val_accuracy: 0.5306
# Epoch 6/10
# 313/313 [==============================] - 105s 335ms/step - loss: 0.6258 - accuracy: 0.5841 - val_loss: 0.6836 - val_accuracy: 0.5410
# Epoch 7/10
# 313/313 [==============================] - 105s 337ms/step - loss: 0.6060 - accuracy: 0.6068 - val_loss: 0.7093 - val_accuracy: 0.5472
# Epoch 8/10
# 313/313 [==============================] - 103s 330ms/step - loss: 0.5862 - accuracy: 0.6179 - val_loss: 0.6963 - val_accuracy: 0.5654
# Epoch 9/10
# 313/313 [==============================] - 103s 331ms/step - loss: 0.5661 - accuracy: 0.6309 - val_loss: 0.7146 - val_accuracy: 0.5440
# Epoch 10/10
# 313/313 [==============================] - 104s 333ms/step - loss: 0.5779 - accuracy: 0.6150 - val_loss: 0.6935 - val_accuracy: 0.5262

# %%
rnn_loss, rnn_accuracy = rnn_model.evaluate(X_test, y_test)
print(f"RNN Test Loss: {rnn_loss}") 
print(f"RNN Test Accuracy: {rnn_accuracy}")
# Out:
# 782/782 [==============================] - 27s 35ms/step - loss: 0.6953 - accuracy: 0.5262
# RNN Test Loss: 0.6952773928642273
# RNN Test Accuracy: 0.5262399911880493

# %% [markdown]
# ## Model LSTM

# %%
lstm_model = Sequential([
    Embedding(input_dim=vocab_size, output_dim=128),
    LSTM(128, activation='tanh', return_sequences=False),
    Dense(1, activation='sigmoid')
])

# %%
lstm_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

lstm_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_3 (Embedding)     (None, None, 128)         1280000
#
#  lstm_1 (LSTM)               (None, 128)               131584
#
#  dense_3 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 1,411,713
# Trainable params: 1,411,713
# Non-trainable params: 0
# _________________________________________________________________

# %%
lstm_history = lstm_model.fit(X_train, y_train,
                            epochs=10,
                            batch_size=64,
                            validation_split=0.2)
# Out:
# Epoch 1/10
# 313/313 [==============================] - 17s 49ms/step - loss: 0.6616 - accuracy: 0.5724 - val_loss: 0.5631 - val_accuracy: 0.7340
# Epoch 2/10
# 313/313 [==============================] - 16s 51ms/step - loss: 0.5987 - accuracy: 0.6633 - val_loss: 0.6752 - val_accuracy: 0.5338
# Epoch 3/10
# 313/313 [==============================] - 15s 49ms/step - loss: 0.5836 - accuracy: 0.6474 - val_loss: 0.6418 - val_accuracy: 0.6204
# Epoch 4/10
# 313/313 [==============================] - 15s 49ms/step - loss: 0.5718 - accuracy: 0.6539 - val_loss: 0.5860 - val_accuracy: 0.6924
# Epoch 5/10
# 313/313 [==============================] - 14s 46ms/step - loss: 0.3577 - accuracy: 0.8569 - val_loss: 0.3568 - val_accuracy: 0.8604
# Epoch 6/10
# 313/313 [==============================] - 14s 46ms/step - loss: 0.2438 - accuracy: 0.9094 - val_loss: 0.3479 - val_accuracy: 0.8688
# Epoch 7/10
# 313/313 [==============================] - 14s 45ms/step - loss: 0.2328 - accuracy: 0.9064 - val_loss: 0.3607 - val_accuracy: 0.8636
# Epoch 8/10
# 313/313 [==============================] - 14s 45ms/step - loss: 0.1441 - accuracy: 0.9530 - val_loss: 0.3862 - val_accuracy: 0.8760
# Epoch 9/10
# 313/313 [==============================] - 14s 45ms/step - loss: 0.2473 - accuracy: 0.8957 - val_loss: 0.4768 - val_accuracy: 0.8290
# Epoch 10/10
# 313/313 [==============================] - 14s 45ms/step - loss: 0.2657 - accuracy: 0.9068 - val_loss: 0.3958 - val_accuracy: 0.8608

# %%
lstm_loss, lstm_accuracy = lstm_model.evaluate(X_test, y_test)
print(f"LSTM Test Loss: {lstm_loss}")
print(f"LSTM Test Accuracy: {lstm_accuracy}")
# Out:
# 782/782 [==============================] - 10s 13ms/step - loss: 0.4209 - accuracy: 0.8498
# LSTM Test Loss: 0.42086613178253174
# LSTM Test Accuracy: 0.8497999906539917
